# %% [markdown]
# # Stochastic optimisation on TSP

# %%
from processing import read_dataset, draw_way, launching, generate_new_dataset
from searches import monte_carlo, random_walk, hill_climb, annealing, genetic_algo, total_dist, l1, l2

# %% [markdown]
# #### 0. Generate dataset
# First, we have to generate random dataset (if we don't have one).

# %%
datafile = generate_new_dataset(100)
data = read_dataset(datafile)
draw_way(data, 'Input', total_dist(data))

# %% [markdown]
# ### Launching algorithms
# Now, let's run our algorithms with different parameters and look at the results.
#
# P.S. Here we demonstrate and visualize with metric distance = `l1`, but you can try l2, using parameter `dist_method_name`=`l1'

# %% [markdown]
# #### 1. Monte Carlo

# %%
launching(datafile, monte_carlo, 'Monte Carlo', 100000)
launching(datafile, monte_carlo, 'Monte Carlo', 1000000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-04441d1e9dc1> in <module>
# ----> 1 launching(datafile, monte_carlo, 'Monte Carlo', 100000)
#       2 launching(datafile, monte_carlo, 'Monte Carlo', 1000000)
#
# ~/work/ITMO/Чтения/optimizers/processing.py in launching(path, method, method_name, iters, dist_method, dist_method_name, **params)
#      61     data = read_dataset(path)
#      62     start = time.time()
# ---> 63     new_data, new_len = method(data, iters=iters, dist_method=dist_method, **params)
#      64     print(f'{time.time() - start} sec')
#      65     print(f'Total distance: {new_len}')
#
# ~/work/ITMO/Чтения/optimizers/searches.py in monte_carlo(cur_order, iters, printDist, dist_method)
#      28     for _ in range(iters):
#      29         cur_order = cur_order[np.random.permutation(cur_order.shape[0]), :]
# ...

# %% [markdown]
# #### 2. Random walk

# %%
launching(datafile, random_walk, 'Random walk', 100000)
launching(datafile, random_walk, 'Random walk', 1000000)
# Out:
# 2.885317087173462 sec
# 24.044944524765015 sec

# %% [markdown]
# #### 3. Hill climb

# %%
launching(datafile, hill_climb, 'Hill climb', 40)
launching(datafile, hill_climb, 'Hill climb', 400)
# Out:
# 11.21703028678894 sec
# 111.28376889228821 sec

# %% [markdown]
# #### 4. Simulated annealing

# %%
launching(datafile, annealing, 'Simulated annealing', 5, delta_t = 0.01, t_max = 500)
launching(datafile, annealing, 'Simulated annealing', 50, delta_t = 0.01, t_max = 500)
# Out:
# 10.898621320724487 sec
# 95.34951734542847 sec

# %% [markdown]
# #### 5. Genetic algorithm

# %%
launching(datafile, genetic_algo, 'Genetic algorithm', 100, size = 500, mut_rate = 0.1, sel_rate = 0.08)
launching(datafile, genetic_algo, 'Genetic algorithm', 1000, size = 500, mut_rate = 0.1, sel_rate = 0.08)
# Out:
# 8.321545124053955 sec
# 81.57140111923218 sec
